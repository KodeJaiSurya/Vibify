# %%
pip install tensorflow_data_validation
# Out:
# Requirement already satisfied: tensorflow_data_validation in /usr/local/lib/python3.10/dist-packages (1.16.1)
# Requirement already satisfied: absl-py<2.0.0,>=0.9 in /usr/local/lib/python3.10/dist-packages (from tensorflow_data_validation) (1.4.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_data_validation) (1.4.2)
# Requirement already satisfied: numpy>=1.22.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_data_validation) (1.26.4)
# Requirement already satisfied: pandas<2,>=1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_data_validation) (1.5.3)
# Requirement already satisfied: pyarrow<11,>=10 in /usr/local/lib/python3.10/dist-packages (from tensorflow_data_validation) (10.0.1)
# Requirement already satisfied: pyfarmhash<0.4,>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow_data_validation) (0.3.2)
# Requirement already satisfied: six<2,>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow_data_validation) (1.16.0)
# Requirement already satisfied: tensorflow<2.17,>=2.16 in /usr/local/lib/python3.10/dist-packages (from tensorflow_data_validation) (2.16.2)
# Requirement already satisfied: tensorflow-metadata<1.17,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_data_validation) (1.16.1)
# Requirement already satisfied: tfx-bsl<1.17,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_data_validation) (1.16.1)
# Requirement already satisfied: apache-beam<3,>=2.47 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (2.60.0)
# Requirement already satisfied: protobuf<5,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow_data_validation) (3.20.3)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.10/dist-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (1.7)
# Requirement already satisfied: orjson<4,>=3.9.7 in /usr/local/lib/python3.10/dist-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (3.10.10)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (0.3.1.1)
# Requirement already satisfied: cloudpickle~=2.2.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (2.2.1)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /usr/local/lib/python3.10/dist-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (1.9.7)
# Requirement already satisfied: fasteners<1.0,>=0.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (0.19)
# Requirement already satisfied: grpcio!=1.48.0,!=1.59.*,!=1.60.*,!=1.61.*,!=1.62.0,!=1.62.1,<1.66.0,<2,>=1.33.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (1.64.1)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (2.7.3)
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in /usr/local/lib/python3.10/dist-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (0.22.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (4.23.0)
# Requirement already satisfied: jsonpickle<4.0.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (3.3.0)
# Requirement already satisfied: objsize<0.8.0,>=0.6.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (0.7.0)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (24.1)
# Requirement already satisfied: pymongo<5.0.0,>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (4.10.1)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (1.25.0)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (1.4.2)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (2.8.2)
# Requirement already satisfied: pytz>=2018.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (2024.2)
# Requirement already satisfied: redis<6,>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (5.2.0)
# Requirement already satisfied: regex>=2020.6.8 in /usr/local/lib/python3.10/dist-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (2024.9.11)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (4.12.2)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (0.23.0)
# Requirement already satisfied: pyarrow-hotfix<1 in /usr/local/lib/python3.10/dist-packages (from apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (0.6)
# Requirement already satisfied: cachetools<6,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (5.5.0)
# Requirement already satisfied: google-api-core<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (2.19.2)
# Requirement already satisfied: google-apitools<0.5.32,>=0.5.31 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (0.5.31)
# Requirement already satisfied: google-auth<3,>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (2.27.0)
# Requirement already satisfied: google-auth-httplib2<0.3.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (0.2.0)
# Requirement already satisfied: google-cloud-datastore<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (2.19.0)
# Requirement already satisfied: google-cloud-pubsub<3,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (2.25.0)
# Requirement already satisfied: google-cloud-pubsublite<2,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (1.11.1)
# Requirement already satisfied: google-cloud-storage<3,>=2.18.2 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (2.18.2)
# Requirement already satisfied: google-cloud-bigquery<4,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (3.25.0)
# Requirement already satisfied: google-cloud-bigquery-storage<3,>=2.6.3 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (2.27.0)
# Requirement already satisfied: google-cloud-core<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (2.4.1)
# Requirement already satisfied: google-cloud-bigtable<3,>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (2.26.0)
# Requirement already satisfied: google-cloud-spanner<4,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (3.49.1)
# Requirement already satisfied: google-cloud-dlp<4,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (3.25.0)
# Requirement already satisfied: google-cloud-language<3,>=2.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (2.13.4)
# Requirement already satisfied: google-cloud-videointelligence<3,>=2.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (2.14.0)
# Requirement already satisfied: google-cloud-vision<4,>=2 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (3.8.0)
# Requirement already satisfied: google-cloud-recommendations-ai<0.11.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (0.10.13)
# Requirement already satisfied: google-cloud-aiplatform<2.0,>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (1.70.0)
# Requirement already satisfied: keyrings.google-artifactregistry-auth in /usr/local/lib/python3.10/dist-packages (from apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (1.1.2)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16->tensorflow_data_validation) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16->tensorflow_data_validation) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16->tensorflow_data_validation) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16->tensorflow_data_validation) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16->tensorflow_data_validation) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16->tensorflow_data_validation) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16->tensorflow_data_validation) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16->tensorflow_data_validation) (3.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16->tensorflow_data_validation) (75.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16->tensorflow_data_validation) (2.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16->tensorflow_data_validation) (1.16.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16->tensorflow_data_validation) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16->tensorflow_data_validation) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.17,>=2.16->tensorflow_data_validation) (0.37.1)
# Requirement already satisfied: google-api-python-client<2,>=1.7.11 in /usr/local/lib/python3.10/dist-packages (from tfx-bsl<1.17,>=1.16.0->tensorflow_data_validation) (1.12.11)
# Requirement already satisfied: tensorflow-serving-api<3,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from tfx-bsl<1.17,>=1.16.0->tensorflow_data_validation) (2.16.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow<2.17,>=2.16->tensorflow_data_validation) (0.44.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3,>=2.0.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (1.65.0)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client<2,>=1.7.11->tfx-bsl<1.17,>=1.16.0->tensorflow_data_validation) (3.0.1)
# Requirement already satisfied: oauth2client>=1.4.12 in /usr/local/lib/python3.10/dist-packages (from google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (4.1.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.18.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (4.9)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (1.13.0)
# Requirement already satisfied: shapely<3.0.0dev in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (2.0.6)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (2.9.2)
# Requirement already satisfied: docstring-parser<1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (0.16)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery<4,>=2.0.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (2.7.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigtable<3,>=2.19.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (0.13.1)
# Requirement already satisfied: grpcio-status>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (1.48.2)
# Requirement already satisfied: opentelemetry-api in /usr/local/lib/python3.10/dist-packages (from google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (1.16.0)
# Requirement already satisfied: opentelemetry-sdk in /usr/local/lib/python3.10/dist-packages (from google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (1.16.0)
# Requirement already satisfied: overrides<8.0.0,>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-pubsublite<2,>=1.2.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (7.7.0)
# Requirement already satisfied: sqlparse>=0.4.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-spanner<4,>=3.0.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (0.5.1)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-spanner<4,>=3.0.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (0.15.4)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage<3,>=2.18.2->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (1.6.0)
# Requirement already satisfied: docopt in /usr/local/lib/python3.10/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (0.6.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<0.23.0,>=0.8->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (3.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (0.20.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.0.0->tensorflow<2.17,>=2.16->tensorflow_data_validation) (13.9.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.0.0->tensorflow<2.17,>=2.16->tensorflow_data_validation) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.0.0->tensorflow<2.17,>=2.16->tensorflow_data_validation) (0.13.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo<5.0.0,>=3.8.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (2.7.0)
# Requirement already satisfied: async-timeout>=4.0.3 in /usr/local/lib/python3.10/dist-packages (from redis<6,>=5.0.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam<3,>=2.47->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tensorflow_data_validation) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tensorflow_data_validation) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tensorflow_data_validation) (3.0.6)
# Requirement already satisfied: keyring in /usr/lib/python3/dist-packages (from keyrings.google-artifactregistry-auth->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (23.5.0)
# Requirement already satisfied: pluggy in /usr/local/lib/python3.10/dist-packages (from keyrings.google-artifactregistry-auth->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (1.5.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client>=1.4.12->google-apitools<0.5.32,>=0.5.31->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (0.6.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3->google-cloud-aiplatform<2.0,>=1.26.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (2.23.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tensorflow_data_validation) (3.0.2)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api->google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (1.2.14)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.37b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-sdk->google-cloud-pubsub<3,>=2.1.0->apache-beam[gcp]<3,>=2.47; python_version < "3.11"->tensorflow_data_validation) (0.37b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.0.0->tensorflow<2.17,>=2.16->tensorflow_data_validation) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.0.0->tensorflow<2.17,>=2.16->tensorflow_data_validation) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow<2.17,>=2.16->tensorflow_data_validation) (0.1.2)

# %%
import tensorflow as tf
import tensorflow_data_validation as tfdv
import pandas as pd
import gdown
print('TFDV Version: {}'.format(tfdv.__version__))
print('Tensorflow Version: {}'.format(tf.__version__))
# Out:
# TFDV Version: 1.16.1
# Tensorflow Version: 2.16.2

# %%
def load_data(file_id: str) -> pd.DataFrame:
    try:
      url = f"https://drive.google.com/uc?id={file_id}"
      file_path = "dataset.csv"
      gdown.download(url, file_path, quiet=False)
      df = pd.read_csv(file_path)
      print("Data loaded successfully.")
      return df

    except FileNotFoundError:
      print("File not found.")
      return None

# %%
file_id = "1zckGHmd_tJfyMqePfol0L-lIScstOCh9"
final_df = load_data(file_id)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1zckGHmd_tJfyMqePfol0L-lIScstOCh9
# To: /content/dataset.csv
# 100%|██████████| 13.6M/13.6M [00:00<00:00, 54.0MB/s]
# Data loaded successfully.
# <ipython-input-3-26d9224e3c33>:6: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
final_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.831   0.814    2    -7.364     1       0.4200        0.0598
# 1         0.719   0.493    8    -7.230     1       0.0794        0.4010
# 2         0.850   0.893    5    -4.783     1       0.0623        0.0138
# 3         0.476   0.781    0    -4.710     1       0.1030        0.0237
# 4         0.798   0.624    2    -7.668     1       0.2930        0.2170
#
#    instrumentalness  liveness  valence  ...                      id  \
# 0          0.013400    0.0556   0.3890  ...  2Vc6NJ9PW9gD9q343XFRKx
# 1          0.000000    0.1180   0.1240  ...  7pgJBLVz5VmnL7uGHmRj6p
# 2          0.000004    0.3720   0.0391  ...  0vSWgAlfpye0WCGeNmuNhy
# 3          0.000000    0.1140   0.1750  ...  0VSXnJqQkwuH2ei1nOQ1nu
# 4          0.000000    0.1660   0.5910  ...  4jCeguq9rMTlbMmPHuO7S3
#
#                                     uri  \
# 0  spotify:track:2Vc6NJ9PW9gD9q343XFRKx
# 1  spotify:track:7pgJBLVz5VmnL7uGHmRj6p
# 2  spotify:track:0vSWgAlfpye0WCGeNmuNhy
# 3  spotify:track:0VSXnJqQkwuH2ei1nOQ1nu
# 4  spotify:track:4jCeguq9rMTlbMmPHuO7S3
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2Vc6NJ9PW9gD...
# 1  https://api.spotify.com/v1/tracks/7pgJBLVz5Vmn...
# 2  https://api.spotify.com/v1/tracks/0vSWgAlfpye0...
# 3  https://api.spotify.com/v1/tracks/0VSXnJqQkwuH...
# 4  https://api.spotify.com/v1/tracks/4jCeguq9rMTl...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2Vc6...      124539
# 1  https://api.spotify.com/v1/audio-analysis/7pgJ...      224427
# 2  https://api.spotify.com/v1/audio-analysis/0vSW...       98821
# 3  https://api.spotify.com/v1/audio-analysis/0VSX...      123661
# 4  https://api.spotify.com/v1/audio-analysis/4jCe...      123298
#
#   time_signature      genre                                      song_name  \
# 0              4  Dark Trap                            Mercury: Retrograde
# 1              4  Dark Trap                                      Pathology
# 2              4  Dark Trap                                       Symbiote
# 3              3  Dark Trap  ProductOfDrugs (Prod. The Virus and Antidote)
# 4              4  Dark Trap                                          Venom
#
#   Unnamed: 0 title
# 0        NaN   NaN
# 1        NaN   NaN
# 2        NaN   NaN
# 3        NaN   NaN
# 4        NaN   NaN
#
# [5 rows x 22 columns]

# %%
data_stats = tfdv.generate_statistics_from_dataframe(final_df)
data_stats
# Out:
# datasets {
#   num_examples: 42305
#   features {
#     type: FLOAT
#     num_stats {
#       common_stats {
#         num_non_missing: 42305
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 42305
#       }
#       mean: 0.6393643210022456
#       std_dev: 0.1566152732579436
#       min: 0.0651
#       median: 0.6459999999999999
#       max: 0.988
#       histograms {
#         buckets {
#           low_value: 0.0651
#           high_value: 0.15739
#           sample_count: 43.76238145416227
#         }
#         buckets {
#           low_value: 0.15739
#           high_value: 0.24968
#           sample_count: 313.6426185458378
#         }
#         buckets {
#           low_value: 0.24968
#           high_value: 0.34197
#           sample_count: 1003.1649999999995
#         }
#         buckets {
#           low_value: 0.34197
#           high_value: 0.43426
#           sample_count: 2956.8799999999997
#         }
#         buckets {
#           low_value: 0.43426
#           high_value: 0.52655
#           sample_count: 6442.924999999997
#         }
#         buckets {
#           low_value: 0.52655
#           high_value: 0.6188400000000001
#           sample_count: 7968.065000000004
#         }
#         buckets {
#           low_value: 0.6188400000000001
#           high_value: 0.71113
#           sample_count: 8161.345000000001
#         }
#         buckets {
#           low_value: 0.71113
#           high_value: 0.80342
#           sample_count: 8520.091
#         }
#         buckets {
#           low_value: 0.80342
#           high_value: 0.89571
#           sample_count: 5482.328999999999
#         }
#         buckets {
#           low_value: 0.89571
#           high_value: 0.988
#           sample_count: 1412.7950000000005
#         }
#       }
#       histograms {
#         buckets {
#           low_value: 0.0651
#           high_value: 0.433
#           sample_count: 4256.0
#         }
#         buckets {
#           low_value: 0.433
#           high_value: 0.5
#           sample_count: 4277.0
#         }
#         buckets {
#           low_value: 0.5
#           high_value: 0.5479999999999999
#           sample_count: 4198.0
#         }
#         buckets {
#           low_value: 0.5479999999999999
#           high_value: 0.597
#           sample_count: 4203.0
#         }
#         buckets {
#           low_value: 0.597
#           high_value: 0.6459999999999999
#           sample_count: 4309.0
#         }
#         buckets {
#           low_value: 0.6459999999999999
#           high_value: 0.6940000000000001
#           sample_count: 4145.0
#         }
#         buckets {
#           low_value: 0.6940000000000001
#           high_value: 0.742
#           sample_count: 4243.0
#         }
#         buckets {
#           low_value: 0.742
#           high_value: 0.7909999999999999
#           sample_count: 4306.0
#         }
#         buckets {
#           low_value: 0.7909999999999999
#           high_value: 0.836
#           sample_count: 4193.0
#         }
#         buckets {
#           low_value: 0.836
#           high_value: 0.988
#           sample_count: 4175.0
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "danceability"
#     }
#   }
#   features {
#     type: FLOAT
#     num_stats {
#       common_stats {
#         num_non_missing: 42305
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 42305
#       }
#       mean: 0.7625155912539888
#       std_dev: 0.18382095862380526
#       min: 0.000243
#       median: 0.8029999999999999
#       max: 1.0
#       histograms {
#         buckets {
#           low_value: 0.000243
#           high_value: 0.1002187
#           sample_count: 36.19959328713255
#         }
#         buckets {
#           low_value: 0.1002187
#           high_value: 0.2001944
#           sample_count: 117.82347337953411
#         }
#         buckets {
#           low_value: 0.2001944
#           high_value: 0.3001701
#           sample_count: 382.4356733333334
#         }
#         buckets {
#           low_value: 0.3001701
#           high_value: 0.4001458
#           sample_count: 1087.7768599999997
#         }
#         buckets {
#           low_value: 0.4001458
#           high_value: 0.5001215
#           sample_count: 2776.5308999999997
#         }
#         buckets {
#           low_value: 0.5001215
#           high_value: 0.6000972
#           sample_count: 4516.857900000001
#         }
#         buckets {
#           low_value: 0.6000972
#           high_value: 0.7000729
#           sample_count: 5649.385100000001
#         }
#         buckets {
#           low_value: 0.7000729
#           high_value: 0.8000486
#           sample_count: 6372.416099999997
#         }
#         buckets {
#           low_value: 0.8000486
#           high_value: 0.9000243
#           sample_count: 8304.825850000001
#         }
#         buckets {
#           low_value: 0.9000243
#           high_value: 1.0
#           sample_count: 13060.748550000006
#         }
#       }
#       histograms {
#         buckets {
#           low_value: 0.000243
#           high_value: 0.496
#           sample_count: 4259.0
#         }
#         buckets {
#           low_value: 0.496
#           high_value: 0.591
#           sample_count: 4204.0
#         }
#         buckets {
#           low_value: 0.591
#           high_value: 0.6679999999999999
#           sample_count: 4245.0
#         }
#         buckets {
#           low_value: 0.6679999999999999
#           high_value: 0.738
#           sample_count: 4227.0
#         }
#         buckets {
#           low_value: 0.738
#           high_value: 0.8029999999999999
#           sample_count: 4256.0
#         }
#         buckets {
#           low_value: 0.8029999999999999
#           high_value: 0.8590000000000001
#           sample_count: 4193.0
#         }
#         buckets {
#           low_value: 0.8590000000000001
#           high_value: 0.904
#           sample_count: 4305.0
#         }
#         buckets {
#           low_value: 0.904
#           high_value: 0.938
#           sample_count: 4156.0
#         }
#         buckets {
#           low_value: 0.938
#           high_value: 0.968
#           sample_count: 4330.0
#         }
#         buckets {
#           low_value: 0.968
#           high_value: 1.0
#           sample_count: 4130.0
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "energy"
#     }
#   }
#   features {
#     num_stats {
#       common_stats {
#         num_non_missing: 42305
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 42305
#       }
#       mean: 5.370239924358823
#       std_dev: 3.6661016023651913
#       num_zeros: 3470
#       median: 6.0
#       max: 11.0
#       histograms {
#         buckets {
#           high_value: 1.1
#           sample_count: 11011.23194444447
#         }
#         buckets {
#           low_value: 1.1
#           high_value: 2.2
#           sample_count: 3051.3394841269796
#         }
#         buckets {
#           low_value: 2.2
#           high_value: 3.3000000000000003
#           sample_count: 904.1142857142859
#         }
#         buckets {
#           low_value: 3.3000000000000003
#           high_value: 4.4
#           sample_count: 2372.181891348087
#         }
#         buckets {
#           low_value: 4.4
#           high_value: 5.5
#           sample_count: 2998.234667093473
#         }
#         buckets {
#           low_value: 5.5
#           high_value: 6.6000000000000005
#           sample_count: 3718.293766876691
#         }
#         buckets {
#           low_value: 6.6000000000000005
#           high_value: 7.700000000000001
#           sample_count: 4279.24320090238
#         }
#         buckets {
#           low_value: 7.700000000000001
#           high_value: 8.8
#           sample_count: 3349.168551701459
#         }
#         buckets {
#           low_value: 8.8
#           high_value: 9.9
#           sample_count: 3258.6908920027354
#         }
#         buckets {
#           low_value: 9.9
#           high_value: 11.0
#           sample_count: 7362.501315789455
#         }
#       }
#       histograms {
#         buckets {
#           high_value: 1.0
#           sample_count: 7238.5
#         }
#         buckets {
#           low_value: 1.0
#           high_value: 1.0
#           sample_count: 3768.5
#         }
#         buckets {
#           low_value: 1.0
#           high_value: 2.0
#           sample_count: 3047.0
#         }
#         buckets {
#           low_value: 2.0
#           high_value: 4.0
#           sample_count: 3268.0
#         }
#         buckets {
#           low_value: 4.0
#           high_value: 6.0
#           sample_count: 6708.0
#         }
#         buckets {
#           low_value: 6.0
#           high_value: 7.0
#           sample_count: 4275.0
#         }
#         buckets {
#           low_value: 7.0
#           high_value: 8.0
#           sample_count: 3345.0
#         }
#         buckets {
#           low_value: 8.0
#           high_value: 9.0
#           sample_count: 3254.0
#         }
#         buckets {
#           low_value: 9.0
#           high_value: 10.0
#           sample_count: 3251.0
#         }
#         buckets {
#           low_value: 10.0
#           high_value: 11.0
#           sample_count: 4150.0
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "key"
#     }
#   }
#   features {
#     type: FLOAT
#     num_stats {
#       common_stats {
#         num_non_missing: 42305
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 42305
#       }
#       mean: -6.465442099042666
#       std_dev: 2.9411303764096206
#       num_zeros: 1
#       min: -33.357
#       median: -6.233
#       max: 3.148
#       histograms {
#         buckets {
#           low_value: -33.357
#           high_value: -29.7065
#           sample_count: 11.500586123525537
#         }
#         buckets {
#           low_value: -29.7065
#           high_value: -26.055999999999997
#           sample_count: 11.500586123525537
#         }
#         buckets {
#           low_value: -26.055999999999997
#           high_value: -22.4055
#           sample_count: 11.500586123525524
#         }
#         buckets {
#           low_value: -22.4055
#           high_value: -18.755
#           sample_count: 30.52686023151475
#         }
#         buckets {
#           low_value: -18.755
#           high_value: -15.104499999999998
#           sample_count: 285.81362738721396
#         }
#         buckets {
#           low_value: -15.104499999999998
#           high_value: -11.454
#           sample_count: 1958.388523241463
#         }
#         buckets {
#           low_value: -11.454
#           high_value: -7.8035
#           sample_count: 9880.769230769232
#         }
#         buckets {
#           low_value: -7.8035
#           high_value: -4.152999999999999
#           sample_count: 21276.375000000007
#         }
#         buckets {
#           low_value: -4.152999999999999
#           high_value: -0.5024999999999977
#           sample_count: 8393.901190476185
#         }
#         buckets {
#           low_value: -0.5024999999999977
#           high_value: 3.148
#           sample_count: 444.7238095238087
#         }
#       }
#       histograms {
#         buckets {
#           low_value: -33.357
#           high_value: -10.217
#           sample_count: 4231.0
#         }
#         buckets {
#           low_value: -10.217
#           high_value: -8.679
#           sample_count: 4238.0
#         }
#         buckets {
#           low_value: -8.679
#           high_value: -7.699
#           sample_count: 4224.0
#         }
#         buckets {
#           low_value: -7.699
#           high_value: -6.912999999999999
#           sample_count: 4228.0
#         }
#         buckets {
#           low_value: -6.912999999999999
#           high_value: -6.233
#           sample_count: 4242.0
#         }
#         buckets {
#           low_value: -6.233
#           high_value: -5.596
#           sample_count: 4217.0
#         }
#         buckets {
#           low_value: -5.596
#           high_value: -4.91
#           sample_count: 4233.0
#         }
#         buckets {
#           low_value: -4.91
#           high_value: -4.074
#           sample_count: 4240.0
#         }
#         buckets {
#           low_value: -4.074
#           high_value: -2.979
#           sample_count: 4222.0
#         }
#         buckets {
#           low_value: -2.979
#           high_value: 3.148
#           sample_count: 4230.0
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "loudness"
#     }
#   }
#   features {
#     num_stats {
#       common_stats {
#         num_non_missing: 42305
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 42305
#       }
#       mean: 0.5494622385060868
#       std_dev: 0.4975474720687133
#       num_zeros: 19060
#       median: 1.0
#       max: 1.0
#       histograms {
#         buckets {
#           high_value: 0.1
#           sample_count: 19064.226363636342
#         }
#         buckets {
#           low_value: 0.1
#           high_value: 0.2
#           sample_count: 4.2263636363636365
#         }
#         buckets {
#           low_value: 0.2
#           high_value: 0.30000000000000004
#           sample_count: 4.226363636363638
#         }
#         buckets {
#           low_value: 0.30000000000000004
#           high_value: 0.4
#           sample_count: 4.226363636363636
#         }
#         buckets {
#           low_value: 0.4
#           high_value: 0.5
#           sample_count: 4.226363636363636
#         }
#         buckets {
#           low_value: 0.5
#           high_value: 0.6000000000000001
#           sample_count: 4.22636363636364
#         }
#         buckets {
#           low_value: 0.6000000000000001
#           high_value: 0.7000000000000001
#           sample_count: 4.226363636363636
#         }
#         buckets {
#           low_value: 0.7000000000000001
#           high_value: 0.8
#           sample_count: 4.226363636363636
#         }
#         buckets {
#           low_value: 0.8
#           high_value: 0.9
#           sample_count: 4.226363636363636
#         }
#         buckets {
#           low_value: 0.9
#           high_value: 1.0
#           sample_count: 23206.962727272803
#         }
#       }
#       histograms {
#         buckets {
#           sample_count: 4765.0
#         }
#         buckets {
#           sample_count: 4765.0
#         }
#         buckets {
#           sample_count: 4765.0
#         }
#         buckets {
#           sample_count: 4765.0
#         }
#         buckets {
#           high_value: 1.0
#           sample_count: 3874.1666666666665
#         }
#         buckets {
#           low_value: 1.0
#           high_value: 1.0
#           sample_count: 3874.1666666666665
#         }
#         buckets {
#           low_value: 1.0
#           high_value: 1.0
#           sample_count: 3874.1666666666665
#         }
#         buckets {
#           low_value: 1.0
#           high_value: 1.0
#           sample_count: 3874.1666666666665
#         }
#         buckets {
#           low_value: 1.0
#           high_value: 1.0
#           sample_count: 3874.1666666666665
#         }
#         buckets {
#           low_value: 1.0
#           high_value: 1.0
#           sample_count: 3874.1666666666665
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "mode"
#     }
#   }
#   features {
#     type: FLOAT
#     num_stats {
#       common_stats {
#         num_non_missing: 42305
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 42305
#       }
#       mean: 0.13656054839853446
#       std_dev: 0.12616645581199917
#       min: 0.0227
#       median: 0.0755
#       max: 0.946
#       histograms {
#         buckets {
#           low_value: 0.0227
#           high_value: 0.11503
#           sample_count: 26861.350000000002
#         }
#         buckets {
#           low_value: 0.11503
#           high_value: 0.20736
#           sample_count: 5591.7300000000005
#         }
#         buckets {
#           low_value: 0.20736
#           high_value: 0.29968999999999996
#           sample_count: 4287.939999999998
#         }
#         buckets {
#           low_value: 0.29968999999999996
#           high_value: 0.39202
#           sample_count: 3285.450000000001
#         }
#         buckets {
#           low_value: 0.39202
#           high_value: 0.48435
#           sample_count: 1547.670000000001
#         }
#         buckets {
#           low_value: 0.48435
#           high_value: 0.57668
#           sample_count: 452.24105263157884
#         }
#         buckets {
#           low_value: 0.57668
#           high_value: 0.66901
#           sample_count: 140.63094736842098
#         }
#         buckets {
#           low_value: 0.66901
#           high_value: 0.76134
#           sample_count: 67.79476056338034
#         }
#         buckets {
#           low_value: 0.76134
#           high_value: 0.85367
#           sample_count: 41.88769199136424
#         }
#         buckets {
#           low_value: 0.85367
#           high_value: 0.946
#           sample_count: 28.305547445255467
#         }
#       }
#       histograms {
#         buckets {
#           low_value: 0.0227
#           high_value: 0.039
#           sample_count: 4256.0
#         }
#         buckets {
#           low_value: 0.039
#           high_value: 0.0457
#           sample_count: 4216.0
#         }
#         buckets {
#           low_value: 0.0457
#           high_value: 0.0527
#           sample_count: 4245.0
#         }
#         buckets {
#           low_value: 0.0527
#           high_value: 0.0618
#           sample_count: 4242.0
#         }
#         buckets {
#           low_value: 0.0618
#           high_value: 0.0755
#           sample_count: 4206.0
#         }
#         buckets {
#           low_value: 0.0755
#           high_value: 0.102
#           sample_count: 4329.0
#         }
#         buckets {
#           low_value: 0.102
#           high_value: 0.154
#           sample_count: 4144.0
#         }
#         buckets {
#           low_value: 0.154
#           high_value: 0.238
#           sample_count: 4224.0
#         }
#         buckets {
#           low_value: 0.238
#           high_value: 0.332
#           sample_count: 4221.0
#         }
#         buckets {
#           low_value: 0.332
#           high_value: 0.946
#           sample_count: 4222.0
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "speechiness"
#     }
#   }
#   features {
#     type: FLOAT
#     num_stats {
#       common_stats {
#         num_non_missing: 42305
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 42305
#       }
#       mean: 0.09616047568230705
#       std_dev: 0.17082457348894
#       min: 1.07e-06
#       median: 0.0164
#       max: 0.988
#       histograms {
#         buckets {
#           low_value: 1.07e-06
#           high_value: 0.098800963
#           sample_count: 31290.475114
#         }
#         buckets {
#           low_value: 0.098800963
#           high_value: 0.197600856
#           sample_count: 4182.846714
#         }
#         buckets {
#           low_value: 0.197600856
#           high_value: 0.29640074899999996
#           sample_count: 2311.2911546666655
#         }
#         buckets {
#           low_value: 0.29640074899999996
#           high_value: 0.395200642
#           sample_count: 1434.7955238333334
#         }
#         buckets {
#           low_value: 0.395200642
#           high_value: 0.494000535
#           sample_count: 955.5955951666672
#         }
#         buckets {
#           low_value: 0.494000535
#           high_value: 0.592800428
#           sample_count: 750.2230918333332
#         }
#         buckets {
#           low_value: 0.592800428
#           high_value: 0.691600321
#           sample_count: 491.1430990384616
#         }
#         buckets {
#           low_value: 0.691600321
#           high_value: 0.790400214
#           sample_count: 419.8704778615383
#         }
#         buckets {
#           low_value: 0.790400214
#           high_value: 0.8892001070000001
#           sample_count: 306.2694489500001
#         }
#         buckets {
#           low_value: 0.8892001070000001
#           high_value: 0.988
#           sample_count: 162.4897806499999
#         }
#       }
#       histograms {
#         buckets {
#           low_value: 1.07e-06
#           high_value: 0.00025
#           sample_count: 4231.0
#         }
#         buckets {
#           low_value: 0.00025
#           high_value: 0.000997
#           sample_count: 4232.0
#         }
#         buckets {
#           low_value: 0.000997
#           high_value: 0.0028399999999999
#           sample_count: 4231.0
#         }
#         buckets {
#           low_value: 0.0028399999999999
#           high_value: 0.00716
#           sample_count: 4229.0
#         }
#         buckets {
#           low_value: 0.00716
#           high_value: 0.0164
#           sample_count: 4249.0
#         }
#         buckets {
#           low_value: 0.0164
#           high_value: 0.0354
#           sample_count: 4223.0
#         }
#         buckets {
#           low_value: 0.0354
#           high_value: 0.074
#           sample_count: 4235.0
#         }
#         buckets {
#           low_value: 0.074
#           high_value: 0.152
#           sample_count: 4236.0
#         }
#         buckets {
#           low_value: 0.152
#           high_value: 0.316
#           sample_count: 4226.0
#         }
#         buckets {
#           low_value: 0.316
#           high_value: 0.988
#           sample_count: 4213.0
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "acousticness"
#     }
#   }
#   features {
#     type: FLOAT
#     num_stats {
#       common_stats {
#         num_non_missing: 42305
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 42305
#       }
#       mean: 0.28304754160808415
#       std_dev: 0.37078671450387124
#       num_zeros: 11313
#       median: 0.00594
#       max: 0.989
#       histograms {
#         buckets {
#           high_value: 0.0989
#           sample_count: 25089.0
#         }
#         buckets {
#           low_value: 0.0989
#           high_value: 0.1978
#           sample_count: 1299.6
#         }
#         buckets {
#           low_value: 0.1978
#           high_value: 0.2967
#           sample_count: 950.2800000000004
#         }
#         buckets {
#           low_value: 0.2967
#           high_value: 0.3956
#           sample_count: 814.9199999999996
#         }
#         buckets {
#           low_value: 0.3956
#           high_value: 0.4945
#           sample_count: 848.199999999999
#         }
#         buckets {
#           low_value: 0.4945
#           high_value: 0.5934
#           sample_count: 957.0000000000017
#         }
#         buckets {
#           low_value: 0.5934
#           high_value: 0.6923
#           sample_count: 1225.9999999999989
#         }
#         buckets {
#           low_value: 0.6923
#           high_value: 0.7912
#           sample_count: 2345.8000000000025
#         }
#         buckets {
#           low_value: 0.7912
#           high_value: 0.8901
#           sample_count: 5406.199999999998
#         }
#         buckets {
#           low_value: 0.8901
#           high_value: 0.989
#           sample_count: 3368.0
#         }
#       }
#       histograms {
#         buckets {
#           sample_count: 5656.5
#         }
#         buckets {
#           sample_count: 5656.5
#         }
#         buckets {
#           high_value: 3.56e-06
#           sample_count: 1379.0
#         }
#         buckets {
#           low_value: 3.56e-06
#           high_value: 0.000158
#           sample_count: 4238.0
#         }
#         buckets {
#           low_value: 0.000158
#           high_value: 0.00594
#           sample_count: 4223.0
#         }
#         buckets {
#           low_value: 0.00594
#           high_value: 0.116
#           sample_count: 4232.0
#         }
#         buckets {
#           low_value: 0.116
#           high_value: 0.5589999999999999
#           sample_count: 4237.0
#         }
#         buckets {
#           low_value: 0.5589999999999999
#           high_value: 0.8
#           sample_count: 4239.0
#         }
#         buckets {
#           low_value: 0.8
#           high_value: 0.877
#           sample_count: 4241.0
#         }
#         buckets {
#           low_value: 0.877
#           high_value: 0.989
#           sample_count: 4203.0
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "instrumentalness"
#     }
#   }
#   features {
#     type: FLOAT
#     num_stats {
#       common_stats {
#         num_non_missing: 42305
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 42305
#       }
#       mean: 0.21407923176929441
#       std_dev: 0.17557360267450584
#       min: 0.0107
#       median: 0.135
#       max: 0.988
#       histograms {
#         buckets {
#           low_value: 0.0107
#           high_value: 0.10843
#           sample_count: 14017.200000000008
#         }
#         buckets {
#           low_value: 0.10843
#           high_value: 0.20615999999999998
#           sample_count: 13515.599999999999
#         }
#         buckets {
#           low_value: 0.20615999999999998
#           high_value: 0.30389
#           sample_count: 4679.250000000001
#         }
#         buckets {
#           low_value: 0.30389
#           high_value: 0.40162
#           sample_count: 5039.419999999999
#         }
#         buckets {
#           low_value: 0.40162
#           high_value: 0.49934999999999996
#           sample_count: 1638.9633333333331
#         }
#         buckets {
#           low_value: 0.49934999999999996
#           high_value: 0.59708
#           sample_count: 1044.216666666668
#         }
#         buckets {
#           low_value: 0.59708
#           high_value: 0.69481
#           sample_count: 1160.449999999999
#         }
#         buckets {
#           low_value: 0.69481
#           high_value: 0.79254
#           sample_count: 544.5679999999999
#         }
#         buckets {
#           low_value: 0.79254
#           high_value: 0.89027
#           sample_count: 377.4661666666667
#         }
#         buckets {
#           low_value: 0.89027
#           high_value: 0.988
#           sample_count: 287.8658333333334
#         }
#       }
#       histograms {
#         buckets {
#           low_value: 0.0107
#           high_value: 0.0752
#           sample_count: 4255.0
#         }
#         buckets {
#           low_value: 0.0752
#           high_value: 0.093
#           sample_count: 4233.0
#         }
#         buckets {
#           low_value: 0.093
#           high_value: 0.106
#           sample_count: 4621.0
#         }
#         buckets {
#           low_value: 0.106
#           high_value: 0.115
#           sample_count: 4060.0
#         }
#         buckets {
#           low_value: 0.115
#           high_value: 0.135
#           sample_count: 4067.0
#         }
#         buckets {
#           low_value: 0.135
#           high_value: 0.175
#           sample_count: 4183.0
#         }
#         buckets {
#           low_value: 0.175
#           high_value: 0.248
#           sample_count: 4232.0
#         }
#         buckets {
#           low_value: 0.248
#           high_value: 0.3339999999999999
#           sample_count: 4210.0
#         }
#         buckets {
#           low_value: 0.3339999999999999
#           high_value: 0.439
#           sample_count: 4218.0
#         }
#         buckets {
#           low_value: 0.439
#           high_value: 0.988
#           sample_count: 4226.0
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "liveness"
#     }
#   }
#   features {
#     type: FLOAT
#     num_stats {
#       common_stats {
#         num_non_missing: 42305
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 42305
#       }
#       mean: 0.3571009573336485
#       std_dev: 0.23319748409073404
#       min: 0.0187
#       median: 0.322
#       max: 0.988
#       histograms {
#         buckets {
#           low_value: 0.0187
#           high_value: 0.11562999999999998
#           sample_count: 7279.4299999999985
#         }
#         buckets {
#           low_value: 0.11562999999999998
#           high_value: 0.21255999999999997
#           sample_count: 7056.41
#         }
#         buckets {
#           low_value: 0.21255999999999997
#           high_value: 0.30949
#           sample_count: 6056.800000000001
#         }
#         buckets {
#           low_value: 0.30949
#           high_value: 0.40641999999999995
#           sample_count: 5916.359999999998
#         }
#         buckets {
#           low_value: 0.40641999999999995
#           high_value: 0.50335
#           sample_count: 4653.950000000001
#         }
#         buckets {
#           low_value: 0.50335
#           high_value: 0.60028
#           sample_count: 3924.3300000000036
#         }
#         buckets {
#           low_value: 0.60028
#           high_value: 0.69721
#           sample_count: 3020.1549999999993
#         }
#         buckets {
#           low_value: 0.69721
#           high_value: 0.79414
#           sample_count: 2229.804999999998
#         }
#         buckets {
#           low_value: 0.79414
#           high_value: 0.8910699999999999
#           sample_count: 1527.9949999999997
#         }
#         buckets {
#           low_value: 0.8910699999999999
#           high_value: 0.988
#           sample_count: 639.765000000001
#         }
#       }
#       histograms {
#         buckets {
#           low_value: 0.0187
#           high_value: 0.0743
#           sample_count: 4242.0
#         }
#         buckets {
#           low_value: 0.0743
#           high_value: 0.134
#           sample_count: 4280.0
#         }
#         buckets {
#           low_value: 0.134
#           high_value: 0.19
#           sample_count: 4218.0
#         }
#         buckets {
#           low_value: 0.19
#           high_value: 0.252
#           sample_count: 4214.0
#         }
#         buckets {
#           low_value: 0.252
#           high_value: 0.322
#           sample_count: 4241.0
#         }
#         buckets {
#           low_value: 0.322
#           high_value: 0.39
#           sample_count: 4226.0
#         }
#         buckets {
#           low_value: 0.39
#           high_value: 0.475
#           sample_count: 4222.0
#         }
#         buckets {
#           low_value: 0.475
#           high_value: 0.573
#           sample_count: 4202.0
#         }
#         buckets {
#           low_value: 0.573
#           high_value: 0.7040000000000001
#           sample_count: 4246.0
#         }
#         buckets {
#           low_value: 0.7040000000000001
#           high_value: 0.988
#           sample_count: 4214.0
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "valence"
#     }
#   }
#   features {
#     type: FLOAT
#     num_stats {
#       common_stats {
#         num_non_missing: 42305
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 42305
#       }
#       mean: 147.4740559035575
#       std_dev: 23.84434149567985
#       min: 57.967
#       median: 144.97299999999998
#       max: 220.29
#       histograms {
#         buckets {
#           low_value: 57.967
#           high_value: 74.1993
#           sample_count: 41.850533223954045
#         }
#         buckets {
#           low_value: 74.1993
#           high_value: 90.4316
#           sample_count: 260.00002621660553
#         }
#         buckets {
#           low_value: 90.4316
#           high_value: 106.6639
#           sample_count: 518.0852083497027
#         }
#         buckets {
#           low_value: 106.6639
#           high_value: 122.8962
#           sample_count: 3263.3383062838093
#         }
#         buckets {
#           low_value: 122.8962
#           high_value: 139.12849999999997
#           sample_count: 12841.895280764636
#         }
#         buckets {
#           low_value: 139.12849999999997
#           high_value: 155.36079999999998
#           sample_count: 13060.718834137668
#         }
#         buckets {
#           low_value: 155.36079999999998
#           high_value: 171.5931
#           sample_count: 3658.621553143966
#         }
#         buckets {
#           low_value: 171.5931
#           high_value: 187.8254
#           sample_count: 5638.023591212994
#         }
#         buckets {
#           low_value: 187.8254
#           high_value: 204.0577
#           sample_count: 2408.888541666669
#         }
#         buckets {
#           low_value: 204.0577
#           high_value: 220.29
#           sample_count: 613.5781249999958
#         }
#       }
#       histograms {
#         buckets {
#           low_value: 57.967
#           high_value: 123.0
#           sample_count: 4227.0
#         }
#         buckets {
#           low_value: 123.0
#           high_value: 127.005
#           sample_count: 4239.0
#         }
#         buckets {
#           low_value: 127.005
#           high_value: 132.005
#           sample_count: 4236.0
#         }
#         buckets {
#           low_value: 132.005
#           high_value: 139.069
#           sample_count: 4217.0
#         }
#         buckets {
#           low_value: 139.069
#           high_value: 144.97299999999998
#           sample_count: 4242.0
#         }
#         buckets {
#           low_value: 144.97299999999998
#           high_value: 149.976
#           sample_count: 4243.0
#         }
#         buckets {
#           low_value: 149.976
#           high_value: 155.007
#           sample_count: 4230.0
#         }
#         buckets {
#           low_value: 155.007
#           high_value: 171.998
#           sample_count: 4215.0
#         }
#         buckets {
#           low_value: 171.998
#           high_value: 180.048
#           sample_count: 4225.0
#         }
#         buckets {
#           low_value: 180.048
#           high_value: 220.29
#           sample_count: 4231.0
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "tempo"
#     }
#   }
#   features {
#     type: STRING
#     string_stats {
#       common_stats {
#         num_non_missing: 42305
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 4230.5
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 42305
#       }
#       unique: 1
#       top_values {
#         value: "audio_features"
#         frequency: 42305.0
#       }
#       avg_length: 14.0
#       rank_histogram {
#         buckets {
#           label: "audio_features"
#           sample_count: 42305.0
#         }
#       }
#     }
#     path {
#       step: "type"
# ...
#           high_rank: 23
#           label: "Dark Techno"
#           sample_count: 263.0
#         }
#         buckets {
#           low_rank: 24
#           high_rank: 24
#           label: "Best Hardstyle ever made"
#           sample_count: 252.0
#         }
#         buckets {
#           low_rank: 25
#           high_rank: 25
#           label: "Psytrance Can"
#           sample_count: 233.0
#         }
#         buckets {
#           low_rank: 26
#           high_rank: 26
#           label: "UPLIFTING TRANCE 2020"
#           sample_count: 228.0
#         }
#         buckets {
#           low_rank: 27
#           high_rank: 27
#           label: "Psytrance 2020"
#           sample_count: 224.0
#         }
#         buckets {
#           low_rank: 28
#           high_rank: 28
#           label: "Lost Lands 2019"
#           sample_count: 222.0
#         }
#         buckets {
#           low_rank: 29
#           high_rank: 29
#           label: "Uplifting Trance, Euphoric Trance"
#           sample_count: 214.0
#         }
#         buckets {
#           low_rank: 30
#           high_rank: 30
#           label: "Tech house"
#           sample_count: 211.0
#         }
#         buckets {
#           low_rank: 31
#           high_rank: 31
#           label: "Tech House 2020"
#           sample_count: 201.0
#         }
#         buckets {
#           low_rank: 32
#           high_rank: 32
#           label: "PsyTrance 2020 felipe"
#           sample_count: 201.0
#         }
#         buckets {
#           low_rank: 33
#           high_rank: 33
#           label: "Techno / Minimal / Hardcore/ Melodic / Dark"
#           sample_count: 188.0
#         }
#         buckets {
#           low_rank: 34
#           high_rank: 34
#           label: "|DARK|HARD|TECHNO"
#           sample_count: 186.0
#         }
#         buckets {
#           low_rank: 35
#           high_rank: 35
#           label: "Riddim Dubstep 2017-2018-2019"
#           sample_count: 181.0
#         }
#         buckets {
#           low_rank: 36
#           high_rank: 36
#           label: "Dirtybird House"
#           sample_count: 177.0
#         }
#         buckets {
#           low_rank: 37
#           high_rank: 37
#           label: "Ready2GetMaggot?"
#           sample_count: 168.0
#         }
#         buckets {
#           low_rank: 38
#           high_rank: 38
#           label: "Drum and Bass - 2015 to 2020"
#           sample_count: 167.0
#         }
#         buckets {
#           low_rank: 39
#           high_rank: 39
#           label: "Anjunabeats Volumes 1 - 14"
#           sample_count: 165.0
#         }
#         buckets {
#           low_rank: 40
#           high_rank: 40
#           label: "Heavy Dubstep"
#           sample_count: 163.0
#         }
#         buckets {
#           low_rank: 41
#           high_rank: 41
#           label: "Riddim or die"
#           sample_count: 158.0
#         }
#         buckets {
#           low_rank: 42
#           high_rank: 42
#           label: "Uplifting | Trance"
#           sample_count: 157.0
#         }
#         buckets {
#           low_rank: 43
#           high_rank: 43
#           label: "Progressive Trance"
#           sample_count: 155.0
#         }
#         buckets {
#           low_rank: 44
#           high_rank: 44
#           label: "Uplifting Trance."
#           sample_count: 154.0
#         }
#         buckets {
#           low_rank: 45
#           high_rank: 45
#           label: "Euphoric Hardstyle - 2020"
#           sample_count: 152.0
#         }
#         buckets {
#           low_rank: 46
#           high_rank: 46
#           label: "Lost Lands 2020"
#           sample_count: 149.0
#         }
#         buckets {
#           low_rank: 47
#           high_rank: 47
#           label: "PsyTrance 2019 By GMR"
#           sample_count: 133.0
#         }
#         buckets {
#           low_rank: 48
#           high_rank: 48
#           label: "blanc | Tech House"
#           sample_count: 130.0
#         }
#         buckets {
#           low_rank: 49
#           high_rank: 49
#           label: "Greatest Hardstyle Playlist"
#           sample_count: 125.0
#         }
#         buckets {
#           low_rank: 50
#           high_rank: 50
#           label: "Best of Trance"
#           sample_count: 123.0
#         }
#         buckets {
#           low_rank: 51
#           high_rank: 51
#           label: "Beatoirt Best New Tech House"
#           sample_count: 118.0
#         }
#         buckets {
#           low_rank: 52
#           high_rank: 52
#           label: "Tech House Essentials by Distortion"
#           sample_count: 104.0
#         }
#         buckets {
#           low_rank: 53
#           high_rank: 53
#           label: "True Techno"
#           sample_count: 93.0
#         }
#         buckets {
#           low_rank: 54
#           high_rank: 54
#           label: "RIDDIM"
#           sample_count: 91.0
#         }
#         buckets {
#           low_rank: 55
#           high_rank: 55
#           label: "Fingah Pistols!"
#           sample_count: 91.0
#         }
#         buckets {
#           low_rank: 56
#           high_rank: 56
#           label: "Psytrance Intensifies (Goa, Psychedelic, Full on)"
#           sample_count: 90.0
#         }
#         buckets {
#           low_rank: 57
#           high_rank: 57
#           label: "Tech House"
#           sample_count: 89.0
#         }
#         buckets {
#           low_rank: 58
#           high_rank: 58
#           label: "Acid Techno"
#           sample_count: 86.0
#         }
#         buckets {
#           low_rank: 59
#           high_rank: 59
#           label: "Best Psytrance 2020"
#           sample_count: 85.0
#         }
#         buckets {
#           low_rank: 60
#           high_rank: 60
#           label: "Tech House Elrow Secrets"
#           sample_count: 84.0
#         }
#         buckets {
#           low_rank: 61
#           high_rank: 61
#           label: "Heavy Hitters"
#           sample_count: 79.0
#         }
#         buckets {
#           low_rank: 62
#           high_rank: 62
#           label: "Psy Trance Full-on Morning"
#           sample_count: 78.0
#         }
#         buckets {
#           low_rank: 63
#           high_rank: 63
#           label: "Liquid Drum and Bass Sessions 2020"
#           sample_count: 78.0
#         }
#         buckets {
#           low_rank: 64
#           high_rank: 64
#           label: "Techno Music 2020 | Best Techno"
#           sample_count: 76.0
#         }
#         buckets {
#           low_rank: 65
#           high_rank: 65
#           label: "Tech House Music 2020"
#           sample_count: 74.0
#         }
#         buckets {
#           low_rank: 66
#           high_rank: 66
#           label: "Tech House Rotation 2020"
#           sample_count: 69.0
#         }
#         buckets {
#           low_rank: 67
#           high_rank: 67
#           label: "Tech House 2020 - Best of Techno"
#           sample_count: 68.0
#         }
#         buckets {
#           low_rank: 68
#           high_rank: 68
#           label: "Drum and Bass 2020 (Drum & Bass Music - DNB Hits)"
#           sample_count: 68.0
#         }
#         buckets {
#           low_rank: 69
#           high_rank: 69
#           label: "ASOT"
#           sample_count: 67.0
#         }
#         buckets {
#           low_rank: 70
#           high_rank: 70
#           label: "Uplifting, Melodic Trance & Vocal Trance"
#           sample_count: 62.0
#         }
#         buckets {
#           low_rank: 71
#           high_rank: 71
#           label: "Techno Bangers"
#           sample_count: 62.0
#         }
#         buckets {
#           low_rank: 72
#           high_rank: 72
#           label: "Tech House Pizza"
#           sample_count: 60.0
#         }
#         buckets {
#           low_rank: 73
#           high_rank: 73
#           label: "BOILER ROOM TECHNO HOUSE"
#           sample_count: 60.0
#         }
#         buckets {
#           low_rank: 74
#           high_rank: 74
#           label: "Tech House by DOT Dance"
#           sample_count: 59.0
#         }
#         buckets {
#           low_rank: 75
#           high_rank: 75
#           label: "Liquid Drum and Bass"
#           sample_count: 56.0
#         }
#         buckets {
#           low_rank: 76
#           high_rank: 76
#           label: "DARK UNDERGROUND TECHNO"
#           sample_count: 55.0
#         }
#         buckets {
#           low_rank: 77
#           high_rank: 77
#           label: "Tech House Club"
#           sample_count: 53.0
#         }
#         buckets {
#           low_rank: 78
#           high_rank: 78
#           label: "Hardstyle 2020 | Updated Weekly"
#           sample_count: 52.0
#         }
#         buckets {
#           low_rank: 79
#           high_rank: 79
#           label: "DARK PSYTRANCE"
#           sample_count: 52.0
#         }
#         buckets {
#           low_rank: 80
#           high_rank: 80
#           label: "TRANNCE 2020 Best Trance Music Official"
#           sample_count: 49.0
#         }
#         buckets {
#           low_rank: 81
#           high_rank: 81
#           label: "PsytranceL Full on Progressive (&Goa)"
#           sample_count: 47.0
#         }
#         buckets {
#           low_rank: 82
#           high_rank: 82
#           label: "Psytrance: Full on New Releases 2020"
#           sample_count: 47.0
#         }
#         buckets {
#           low_rank: 83
#           high_rank: 83
#           label: "Toolroom Tech House"
#           sample_count: 45.0
#         }
#         buckets {
#           low_rank: 84
#           high_rank: 84
#           label: "Tech House Bangerz"
#           sample_count: 45.0
#         }
#         buckets {
#           low_rank: 85
#           high_rank: 85
#           label: "PsyTrance 2020/ Progressive PsyTrance Mix"
#           sample_count: 45.0
#         }
#         buckets {
#           low_rank: 86
#           high_rank: 86
#           label: "Top Techno Tracks 2020"
#           sample_count: 44.0
#         }
#         buckets {
#           low_rank: 87
#           high_rank: 87
#           label: "Techno Bangers: Bunker Style"
#           sample_count: 44.0
#         }
#         buckets {
#           low_rank: 88
#           high_rank: 88
#           label: "Riddim Dubstep"
#           sample_count: 44.0
#         }
#         buckets {
#           low_rank: 89
#           high_rank: 89
#           label: "Melodic Hardstyle 2020"
#           sample_count: 44.0
#         }
#         buckets {
#           low_rank: 90
#           high_rank: 90
#           label: "Trance 100 Chart - by Armada Music"
#           sample_count: 43.0
#         }
#         buckets {
#           low_rank: 91
#           high_rank: 91
#           label: "Minimal Techno: The Dark Undergound"
#           sample_count: 43.0
#         }
#         buckets {
#           low_rank: 92
#           high_rank: 92
#           label: "Tech House Top 50"
#           sample_count: 42.0
#         }
#         buckets {
#           low_rank: 93
#           high_rank: 93
#           label: "PsyTrance 2020 By GMR"
#           sample_count: 42.0
#         }
#         buckets {
#           low_rank: 94
#           high_rank: 94
#           label: "DRUM & BASS 2020"
#           sample_count: 41.0
#         }
#         buckets {
#           low_rank: 95
#           high_rank: 95
#           label: "Uplifting Trance 2019"
#           sample_count: 40.0
#         }
#         buckets {
#           low_rank: 96
#           high_rank: 96
#           label: "Tech House Movement"
#           sample_count: 40.0
#         }
#         buckets {
#           low_rank: 97
#           high_rank: 97
#           label: "Best of PsyTrance"
#           sample_count: 40.0
#         }
#         buckets {
#           low_rank: 98
#           high_rank: 98
#           label: "UKF Drum & Bass"
#           sample_count: 37.0
#         }
#         buckets {
#           low_rank: 99
#           high_rank: 99
#           label: "Psytrance Supernova"
#           sample_count: 37.0
#         }
#         buckets {
#           low_rank: 100
#           high_rank: 100
#           label: "Drum and Bass Top 50"
#           sample_count: 36.0
#         }
#         buckets {
#           low_rank: 101
#           high_rank: 101
#           label: "Drum and Bass - Running 2020"
#           sample_count: 36.0
#         }
#         buckets {
#           low_rank: 102
#           high_rank: 102
#           label: "Acid Techno: Hard Techno on Acid"
#           sample_count: 36.0
#         }
#         buckets {
#           low_rank: 103
#           high_rank: 103
#           label: "RIDDIM 2020 & Riddim Hits"
#           sample_count: 35.0
#         }
#         buckets {
#           low_rank: 104
#           high_rank: 104
#           label: "Hardstyle Remixes of Popular Songs!"
#           sample_count: 35.0
#         }
#         buckets {
#           low_rank: 105
#           high_rank: 105
#           label: "Massive Drum & Bass"
#           sample_count: 34.0
#         }
#         buckets {
#           low_rank: 106
#           high_rank: 106
#           label: "Techno Bunker"
#           sample_count: 33.0
#         }
#         buckets {
#           low_rank: 107
#           high_rank: 107
#           label: "Trance Mission"
#           sample_count: 32.0
#         }
#         buckets {
#           low_rank: 108
#           high_rank: 108
#           label: "TECHNO Complex 2020"
#           sample_count: 32.0
#         }
#         buckets {
#           low_rank: 109
#           high_rank: 109
#           label: "Stepping Out"
#           sample_count: 32.0
#         }
#         buckets {
#           low_rank: 110
#           high_rank: 110
#           label: "Buygore: Dubstep, Riddim, Trap and More"
#           sample_count: 32.0
#         }
#         buckets {
#           low_rank: 111
#           high_rank: 111
#           label: "TRANCE 2020 TRANCE MUSIC 2020"
#           sample_count: 31.0
#         }
#         buckets {
#           low_rank: 112
#           high_rank: 112
#           label: "Q-Dance | Hardstyle | Top 100 | 2019"
#           sample_count: 31.0
#         }
#         buckets {
#           low_rank: 113
#           high_rank: 113
#           label: "Techno Top 50"
#           sample_count: 27.0
#         }
#         buckets {
#           low_rank: 114
#           high_rank: 114
#           label: "Techno Music Matters"
#           sample_count: 27.0
#         }
#         buckets {
#           low_rank: 115
#           high_rank: 115
#           label: "Hardstyle Daily"
#           sample_count: 27.0
#         }
#         buckets {
#           low_rank: 116
#           high_rank: 116
#           label: "Hardstyle || HARD with STYLE Playlist"
#           sample_count: 25.0
#         }
#         buckets {
#           low_rank: 117
#           high_rank: 117
#           label: "Hardstyle by Q-dance"
#           sample_count: 25.0
#         }
#         buckets {
#           low_rank: 118
#           high_rank: 118
#           label: "Hardstyle 2020"
#           sample_count: 23.0
#         }
#         buckets {
#           low_rank: 119
#           high_rank: 119
#           label: "Drum & Bass 2020"
#           sample_count: 23.0
#         }
#         buckets {
#           low_rank: 120
#           high_rank: 120
#           label: "Trap and Bass"
#           sample_count: 22.0
#         }
#         buckets {
#           low_rank: 121
#           high_rank: 121
#           label: "Techno 2020"
#           sample_count: 22.0
#         }
#         buckets {
#           low_rank: 122
#           high_rank: 122
#           label: "Progressive & Melodic Trance"
#           sample_count: 22.0
#         }
#         buckets {
#           low_rank: 123
#           high_rank: 123
#           label: "Techno Daily"
#           sample_count: 21.0
#         }
#         buckets {
#           low_rank: 124
#           high_rank: 124
#           label: "Riddim Lords"
#           sample_count: 21.0
#         }
#         buckets {
#           low_rank: 125
#           high_rank: 125
#           label: "Hardstyle Hits "
#           sample_count: 20.0
#         }
#         buckets {
#           low_rank: 126
#           high_rank: 126
#           label: "Trance List | TOP Trance"
#           sample_count: 18.0
#         }
#         buckets {
#           low_rank: 127
#           high_rank: 127
#           label: "Hardstlye - 2020"
#           sample_count: 18.0
#         }
#         buckets {
#           low_rank: 128
#           high_rank: 128
#           label: "EDC 2020 Bass Pod"
#           sample_count: 16.0
#         }
#         buckets {
#           low_rank: 129
#           high_rank: 129
#           label: "Best New Techno - When We Dip"
#           sample_count: 13.0
#         }
#         buckets {
#           low_rank: 130
#           high_rank: 130
#           label: "Trap & Bass 2020"
#           sample_count: 12.0
#         }
#         buckets {
#           low_rank: 131
#           high_rank: 131
#           label: "HALCYON\'s 808 BASEMENT"
#           sample_count: 12.0
#         }
#       }
#     }
#     path {
#       step: "title"
#     }
#   }
# }

# %%
tfdv.visualize_statistics(data_stats)
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %%
# Infer schema from the computed statistics.
schema = tfdv.infer_schema(statistics=data_stats)

# Display the inferred schema
tfdv.display_schema(schema)
# Out:
#                       Type  Presence Valency   Domain
# Feature name
# 'danceability'       FLOAT  required                -
# 'energy'             FLOAT  required                -
# 'key'                  INT  required                -
# 'loudness'           FLOAT  required                -
# 'mode'                 INT  required                -
# 'speechiness'        FLOAT  required                -
# 'acousticness'       FLOAT  required                -
# 'instrumentalness'   FLOAT  required                -
# 'liveness'           FLOAT  required                -
# 'valence'            FLOAT  required                -
# 'tempo'              FLOAT  required                -
# 'type'              STRING  required           'type'
# 'id'                 BYTES  required                -
# 'uri'                BYTES  required                -
# 'track_href'         BYTES  required                -
# 'analysis_url'       BYTES  required                -
# 'duration_ms'          INT  required                -
# 'time_signature'       INT  required                -
# 'genre'             STRING  required          'genre'
# 'song_name'          BYTES  optional  single        -
# 'Unnamed: 0'         FLOAT  optional  single        -
# 'title'              BYTES  optional  single        -
#                                                                                                                                                                Values
# Domain
# 'type'                                                                                                                                               'audio_features'
# 'genre'  'Dark Trap', 'Emo', 'Hiphop', 'Pop', 'Rap', 'RnB', 'Trap Metal', 'Underground Rap', 'dnb', 'hardstyle', 'psytrance', 'techhouse', 'techno', 'trance', 'trap'

# %%
anomalies =  tfdv.validate_statistics(statistics=data_stats, schema=schema)

# Visualize anomalies
tfdv.display_anomalies(anomalies)
# Out:
# <h4 style="color:green;">No anomalies found.</h4>

# %%
type(anomalies)
# Out:
# tensorflow_metadata.proto.v0.anomalies_pb2.Anomalies

# %%
import tensorflow as tf
import tensorflow_data_validation as tfdv
import pandas as pd
import gdown

# %%
def getSchema(df):
  data_stats = tfdv.generate_statistics_from_dataframe(df)
  schema = tfdv.infer_schema(statistics=data_stats)
  tfdv.display_schema(schema)
  return schema

# %%
def getAnomalies(df):
  data_stats = tfdv.generate_statistics_from_dataframe(df)
  schema = tfdv.infer_schema(statistics=data_stats)
  anomalies =  tfdv.validate_statistics(statistics=data_stats, schema=schema)
  if anomalies.anomaly_info:
    # Display anomalies if present
    tfdv.display_anomalies(anomalies)
    print("Anomalies detected in the data!")
  else:
    print("No anomalies detected.")

# %%
def getAnomalies(df):
    # Generate data statistics from the input DataFrame, Infer a schema from statistics, and identify anomalies
    data_stats = tfdv.generate_statistics_from_dataframe(df)
    schema = tfdv.infer_schema(statistics=data_stats)
    anomalies = tfdv.validate_statistics(statistics=data_stats, schema=schema)

    # Check if any anomalies are detected
    if anomalies.anomaly_info:
        tfdv.display_anomalies(anomalies)
        print("Anomalies detected in the data!")
    else:
        print("No anomalies detected.")

# %%
getAnomalies(final_df)
# Out:
# No anomalies detected.

# %%
getAnomalies(load_data("1QywNP548AN2OIQo_o-goK3EBqQH3desz"))
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1QywNP548AN2OIQo_o-goK3EBqQH3desz
# From (redirected): https://drive.google.com/uc?id=1QywNP548AN2OIQo_o-goK3EBqQH3desz&confirm=t&uuid=342289d4-9a83-4593-9420-930dba6fa71f
# To: /content/dataset.csv
# 100%|██████████| 301M/301M [00:08<00:00, 34.9MB/s]
# Data loaded successfully.
# No anomalies detected.
